# %% [markdown]
# <a href="https://colab.research.google.com/github/chin0104/DPDM2023/blob/main/Data102_(Chapter2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ขั้นที่ 1 Eyesball the Data
#
# ## Open CSV File

# %%
import os #จัดการ file และ path
import pandas as pd #จัดการข้อมูลลักษณะตาราง

# %%
path ='/content/drive/MyDrive/DPDM65/' #ที่อยู่ของข้อมูลที่โหลดมา
path
# Out:
# '/content/drive/MyDrive/DPDM65/'

# %%
data = pd.read_csv('/content/csv') #pd.read_csv(os.path.join(ที่อยู่ไฟล์,ชื่อไฟล์))
data
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 70                17                    29
# 7       May   2566                101                26                    47
# 8      June   2566                101                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# ...

# %%
data.loc[6,'Amount_Government'] = 80
data
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 80                17                    29
# 7       May   2566                101                26                    47
# 8      June   2566                101                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# ...

# %% [markdown]
# #standard medtrod

# %% [markdown]
# *NaN : Not a Number* (เป็นช่องว่าง)

# %% [markdown]
# ###table view

# %% [markdown]
# ### **Selection:**

# %%
data['Amount_Government'][6] = 81
# Out:
# <ipython-input-73-1dc767d492ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amount_Government'][6] = 81

# %%
data
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 81                17                    29
# 7       May   2566                101                26                    47
# 8      June   2566                101                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# ...

# %% [markdown]
# ### array view

# %% [markdown]
# *Cannot specify date ส่งผลตรวจแต่ไม่ลงวันที่*

# %%
data.iloc[-1,2] = 130

# %%
data
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 81                17                    29
# 7       May   2566                101                26                    47
# 8      June   2566                130                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# ...

# %% [markdown]
# ### **head(), tail()**

# %% [markdown]
# # **3 Boxplot**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - IQR (Interquartile range): ช่วงของ Q1, Q2, Q3 :ถ้าเลยขอบนี้จะถือเป็น Outlier
# - ขอบล่าง = Q1-1.5*IQR
# - ขอบบน = Q1+1.5*IQR

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(data['Amount_Government'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77fef564e8f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x77fef564ee30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x77fef564e650>],
#  'medians': [<matplotlib.lines.Line2D at 0x77fef564f370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77fef564f610>],
#  'means': []}

# %% [markdown]
# - *Library: matplotlib สำหรับวาดรูป plot graph, packet : pyplot  ตั้งชื่อว่า plt*

# %% [markdown]
# ### take values from the box plot
# ```

# %%
bp_out = plt.boxplot(data['Amount_Government'])

# %%
bp_out
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77fef56c9540>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x77fef56c9ab0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x77fef56c92a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x77fef56c9ff0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77fef56ca290>],
#  'means': []}

# %%
bp_out['fliers']

# %%
bp_out['fliers'][0]

# %%
bp_out['fliers'][0].get_ydata()
# Out:
# array([ 81, 130])

# %%
bp_out['fliers'][0].get_ydata()[0]
# Out:
# 81

# %%
bp_out['fliers'][0].get_ydata()[1]
# Out:
# 130

# %% [markdown]
# # quering and filtering

# %%
data
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6     April   2566                 81                17                    29
# 7       May   2566                101                26                    47
# 8      June   2566                130                25                    39
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# ...

# %% [markdown]
# DataFrame[list_oflogics]

# %%
data[[False,False,False,True,False,True,False,False,False]]
# Out:
#     Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 3  January   2566                 94                18                    27
# 5    March   2566                100                22                    33
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 3                      3                        4.5                     47
# 5                      2                        4.0                     47
#
#    Amount_ Day_Vacationleave
# 3                       69.5
# 5                       75.0

# %% [markdown]
# ### Creating list of logics

# %% [markdown]
# all rows that have amount_sickleave equal to 20

# %%
data['Amount_Sickleave'] == 20
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Amount_Sickleave, dtype: bool

# %%
data[data['Amount_Sickleave'] == 20]
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 1  November   2565                 95                20                    57
# 4  February   2566                100                20                    30
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 1                      0                        0.0                     31
# 4                      2                        5.0                     32
#
#    Amount_ Day_Vacationleave
# 1                       47.0
# 4                       60.0

# %% [markdown]
# # quiz 3
#
# filter out the outliner rows ($'Amount_Government'$)

# %%
data = pd.read_csv('/content/csv')
data.loc[6,'Amount_Government'] = 80
data['Amount_Government'][6] = 81
data.iloc[-3,2] = 83
data.iloc[-1,2] = 130
bp_out = plt.boxplot(data['Amount_Government'])
bp_out['fliers'][0].get_ydata()[0]
bp_out['fliers'][0].get_ydata()[1]
# Out:
# <ipython-input-106-69936629ddee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amount_Government'][6] = 81
# 130

# %%
for i in range(0,9) :
    if  data['Amount_Government'][i] == bp_out['fliers'][0].get_ydata()[0]:
      print(f'month {i} = true')
    elif data['Amount_Government'][i] == bp_out['fliers'][0].get_ydata()[1]:
      print(f'month {i} = true')
    else:
      print(f'month {i} = false')
# Out:
# month 0 = false
# month 1 = false
# month 2 = false
# month 3 = false
# month 4 = false
# month 5 = false
# month 6 = true
# month 7 = false
# month 8 = true

# %%
data = data.drop(6,axis=0)
data = data.drop(8,axis=0)
df1 = data.reset_index(drop=True)

# %%
data = pd.read_csv('/content/csv')
data.loc[6,'Amount_Government'] = 80
data['Amount_Government'][6] = 81
data.iloc[-3,2] = 83
data.iloc[-1,2] = 130
bp_out = plt.boxplot(data['Amount_Government'])
bp_out['fliers'][0].get_ydata()[0]
bp_out['fliers'][0].get_ydata()[1]
# Out:
# <ipython-input-109-69936629ddee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Amount_Government'][6] = 81
# 130

# %%
df2 = data[(data['Amount_Government'] != 83) & (data['Amount_Government'] != 130)]

# %%
df1
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 6       May   2566                101                26                    47
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# 1                      0                        0.0                     31
# 2                      3                        4.5                     47
# ...

# %%
df2
# Out:
#      Month_  Year_  Amount_Government  Amount_Sickleave  Amount_Day_Sickleave  \
# 0   October   2565                 95                18                    28
# 1  November   2565                 95                20                    57
# 2  December   2565                 94                18                    27
# 3   January   2566                 94                18                    27
# 4  February   2566                100                20                    30
# 5     March   2566                100                22                    33
# 7       May   2566                101                26                    47
#
#    Amount_ Personalleave  Amount_ Day_Personalleave  Amount_ Vacationleave  \
# 0                      1                        2.0                     35
# 1                      0                        0.0                     31
# 2                      3                        4.5                     47
# ...

# %%
positive_ = data_new.positive.tolist()
# data_new.iloc[:,1]
# data_new.iloc[:,1:2]
# data_new.iloc[:,1:-1]
Total_ = data_new['Total Testing'].tolist()
# data_new.iloc[:,-1:] #as same to create the list
# data_new.iloc[:,2:3]
# data_new.iloc[:,3]

plt.boxplot(positive_) #positive
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33bb551350>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33bb56cc50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33bb55d190>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33bb574750>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33bb56c1d0>,
#   <matplotlib.lines.Line2D at 0x7f33bb56c710>]}

# %%
plt.boxplot(Total_) #Total Testing
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33bb02dcd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33bb0484d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33bb050510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33bb048f90>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33bb043a10>,
#   <matplotlib.lines.Line2D at 0x7f33bb043f50>]}

# %% [markdown]
# ดูตั้งเเต่ 1 มิถุนายน ที่มีค่าเป็น positive
# - ย้อนหลังไป 54 วัน

# %%
plt.boxplot(data_new.iloc[-54:,1])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33bafe4910>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33baf81150>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33baf8a190>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33baf81c10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33baf78690>,
#   <matplotlib.lines.Line2D at 0x7f33baf78bd0>]}

# %% [markdown]
# ดูตั้งเเต่ 1 มิถุนายน, Total Testing

# %%
plt.boxplot(data_new.iloc[-54:,2]) #
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33baf60550>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33baef3d10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33baefbd50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33baefb810>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33baef3290>,
#   <matplotlib.lines.Line2D at 0x7f33baef37d0>]}

# %% [markdown]
# # **4 Plot all datapoints (depend on data type)**
#
# Plot ดูการกระจายของข้อมูล

# %% [markdown]
# ## Time Series:

# %%
# x: วันที่
# y: จำนวนผู้ป่วย

# %%
y = data_new.iloc[1:,1] #positive
plt.plot(y)

# %%
y = data_new.iloc[1:,2] #Total Testing
plt.plot(y)

# %% [markdown]
# ### Quiz 6 plot time series ของ Positive และTotal Testing โดยตัด outlier
# - จากค่าาสังเกต: column ' positive ' เเละ ' Total Testing' value น่าจะสลับที่กัน ??
# *ดังนั้น ต้อง Plot โดยตัด 7 rows สุดท้ายออกไป

# %%
data_new[565:571:] ###ข้อมูลใหม่ ไม่มี outlier แล้ว
# Out:
#           Date  positive  Total Testing
# 566  19/7/2021      9466          64522
# 567  20/7/2021     10152          68403
# 568  21/7/2021     12210          82325
# 569  22/7/2021     10623          62846
# 570  23/7/2021     10200          58851
# 571  24/7/2021     13745          67283

# %%
y = data_new.iloc[1:-7,1] #positive
plt.plot(y,'r')

# %%
y = data_new.iloc[:-7,2] #Total Testing
plt.plot(y)

# %%
#plot 2 เส้นใน 1 กราฟ
y = data_new.iloc[:-7,1] #positive
plt.plot(y,'r')
y = data_new.iloc[:-7,2] #Total Testing
plt.plot(y)

# %% [markdown]
# ถ้ายังไม่ลบ outlier

# %%
#ยังไม่ลบ outlier
y = data_new.iloc[500:,1] #positive
plt.plot(y,'r')
y = data_new.iloc[500:,2] #Total Testing
plt.plot(y)
#สามารถมองเเล้วตอบได้ว่ามันสลับที่กัน ของ values 2 ตัวแปรนี้ (อันนี้ข้อมูลที่โหลดมาใหม่เลยไม่มี)หก

# %%
y = data_new.iloc[510:520,1] #positive
plt.plot(y,'r')
y = data_new.iloc[510:520,2] #Total Testing
plt.plot(y)

# %%
data_new.iloc[512,:] #ตัดเเถวเเรกไปเเล้ว index เลยเลื่อน จริงๆ เป็น index 513
# Out:
# Date             27/5/2021
# positive             10438
# Total Testing        73756
# Name: 513, dtype: object

# %%
data.iloc[513,:3] #ตัดเเถวเเรกไปเเล้ว index เลยเลื่อน จริงๆ เป็น index 513 ใน dataframe ที่ยังไม่ตัด NaN
# Out:
# Date             27/5/2021
# positive             10438
# Total Testing        73756
# Name: 513, dtype: object

# %%
data_new.iloc[513,:]
# Out:
# Date             28/5/2021
# positive              3698
# Total Testing        75041
# Name: 514, dtype: object

# %%
y = data_new.iloc[500:-7,1] #positive
plt.plot(y,'r')

# %% [markdown]
# # **Data Covid case by case (HW)**

# %%
import pandas as pd
data_civid_cases = pd.read_csv( '/content/drive/MyDrive/DPDM65/confirmed-cases.csv')
data_civid_cases.head(3)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
#
#   district_of_onset
# 0               NaN
# 1               NaN
# 2             เมือง

# %% [markdown]
# ## 1. Eyesball the Data

# %% [markdown]
# ###  Meta Data
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - อีก 1 ตัวแปร คือ risk: ความเสี่ยง, สถานที่เสี่ยง, พบความเสี่ยงมาจาก

# %%
#สนใจวันที่ 513
data_civid_cases[data_civid_cases['Notified date'] == '26/5/2021']
# Out:
#            No. announce_date Notified date   sex   age Unit    nationality  \
# 135499  135500     26/5/2021     26/5/2021   ชาย  66.0   ปี       Thailand
# 137894  137895     27/5/2021     26/5/2021   NaN  60.0   ปี            NaN
# 137895  137896     27/5/2021     26/5/2021   NaN  33.0   ปี            NaN
# 137896  137897     27/5/2021     26/5/2021   NaN  39.0   ปี            NaN
# 137897  137898     27/5/2021     26/5/2021   NaN  30.0   ปี            NaN
# ...        ...           ...           ...   ...   ...  ...            ...
# 141212  141213     27/5/2021     26/5/2021   ชาย  21.0   ปี        Burmese
# 141213  141214     27/5/2021     26/5/2021   ชาย  21.0   ปี            NaN
# 141214  141215     27/5/2021     26/5/2021  หญิง  18.0   ปี  Laotian / Lao
# 141215  141216     27/5/2021     26/5/2021   ชาย  24.0   ปี       Thailand
# 141216  141217     27/5/2021     26/5/2021   ชาย  56.0   ปี       Thailand
#
#        province_of_isolation  \
# 135499              ปทุมธานี
# ...

# %%
data_civid_cases.head()
# Out:
#    No. announce_date Notified date   sex   age Unit nationality  \
# 0    1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1    2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2    3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3    4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4    5     24/1/2020           NaN  หญิง  66.0   ปี       China
#
#   province_of_isolation                              risk province_of_onset  \
# 0         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 1         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 2                นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม
# 3         กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
# 4               นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร
#
#   district_of_onset
# 0               NaN
# 1               NaN
# 2             เมือง
# 3               NaN
# ...

# %%
data_civid_cases.tail()
# Out:
#            No. announce_date Notified date  sex   age Unit nationality  \
# 839766  839767     12/8/2021     11/8/2021  ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021  ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021  ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021  ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021  ชาย  47.0   ปี    Thailand
#
#        province_of_isolation              risk province_of_onset  \
# 839766             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839767             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839768             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839769             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
# 839770             กาญจนบุรี  ทัณฑสถาน/เรือนจำ         กาญจนบุรี
#
#        district_of_onset
# 839766               NaN
# 839767               NaN
# 839768               NaN
# 839769               NaN
# ...

# %% [markdown]
# ## 2. Statical deacriptive

# %%
data_civid_cases.describe() #Age ใช้ได้ ,No. ใช้ได้เเค่ count
#มีคนเป็น โควิดเเล้วทั้งหมด  512,622 คน ในประเทศไทย
# คนที่เป็น covid ส่วนใหญ่อายุ  34 ปี
# อายุมากที่สุดที่เป็น covid คือ 108 ปี
# อายุน้อยที่สุดที่เป็น covid คือ 1 ปี
# Out:
#                  No.
# count  839771.000000
# mean   419886.000000
# std    242421.150791
# min         1.000000
# 25%    209943.500000
# 50%    419886.000000
# 75%    629828.500000
# max    839771.000000

# %%
data_civid_cases['age'] = data_civid_cases['age'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-bc47d5c0da07> in <module>()
# ----> 1 data_civid_cases['age'] = data_civid_cases['age'].astype(float)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
age_str, age_i = [], []
for i in range(len(data_civid_cases)) :
    age = data_civid_cases['age'][i]
    if type(age) == str and '/' in age:
      age_str.append(age)
      age_i.append(i)

# %%
print(data_civid_cases.shape)
print(len(age_str))
print(len(age_i))
# Out:
# (839771, 11)
# 1
# 1

# %%
#age_i

# %%
age_str ##น่าจะอายุ 55 ปี
# Out:
# ['55/664']

# %%
data_civid_cases.iloc[[age_i[0]]]
# Out:
#            No. announce_date Notified date   sex     age Unit nationality  \
# 100164  100165     16/5/2021     15/5/2021  หญิง  55/664  NaN    Thailand
#
#        province_of_isolation                                         risk  \
# 100164                ภูเก็ต  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 100164            ภูเก็ต             เมือง

# %%
data_civid_cases.loc[data_civid_cases.index[[age_i[0]]], 'age'] = 55
data_civid_cases.iloc[[age_i[0]]]
# Out:
#            No. announce_date Notified date   sex age Unit nationality  \
# 100164  100165     16/5/2021     15/5/2021  หญิง  55  NaN    Thailand
#
#        province_of_isolation                                         risk  \
# 100164                ภูเก็ต  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
#        province_of_onset district_of_onset
# 100164            ภูเก็ต             เมือง

# %% [markdown]
# *แก้ไข rows ที่มีอายุ มีเครื่องหมาย '/' เรียบร้อย *

# %%
data_civid_cases['age'] = data_civid_cases['age'].astype(float)

# %%
data_civid_cases.describe()
# Out:
#                  No.            age
# count  839771.000000  763606.000000
# mean   419886.000000      35.700134
# std    242421.150791      16.597803
# min         1.000000       0.750000
# 25%    209943.500000      24.000000
# 50%    419886.000000      34.000000
# 75%    629828.500000      46.000000
# max    839771.000000     440.000000

# %% [markdown]
# ```
# data_civid_cases[data_civid_cases['age'] > 100]
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Boxplot

# %%
from matplotlib import pyplot as plt
plt.boxplot(data_civid_cases['age'].dropna()) # plt.boxplot(data_civid_cases.iloc[:,4].dropna())
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33b6ac12d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33b6ab8c10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33b6ac2c50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33b6ac2710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33b6ab8190>,
#   <matplotlib.lines.Line2D at 0x7f33b6ab86d0>]}

# %% [markdown]
# - เหตุผลที่คนเเก่ที่ติดโควิดมีจำนวนน้อยเเละไม่ได้เป็นตัวเเทนในสถิติ คนที่ติดโควิด
# >- เพราะคนเเก่ ระวังตัวสูง ไม่ค่อยได้ไปไหน,
# >- เเต่ติดเเล้วโอกาสรอดน้อยด้วยโรคประจำตัวเยอะ, ส่วนใหญ่ติดก็ไม่ได้พาไปหาหมอ

# %%
data_civid_cases[['No.','sex']].groupby('sex').count() #จะได้ว่าพบ ค่าที่ไม่สอดคล้องอยู่ 1 ค่า คือ 'นาย'
# Out:
#          No.
# sex
# ชาย   384994
# นาย        1
# หญิง  399881

# %%
df = data_civid_cases[['No.','risk']].dropna().groupby('risk').count()
df
# Out:
#                                                      No.
# risk
#  Samui plus                                            2
# 10.อื่นๆ                                              22
# 2.สัมผัสผู้ติดเชื้อ                                   10
# ACF รองเมือง                                          24
# ACF สนามกีฬาธูปะเตมีย์                                23
# ...                                                  ...
# ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว      18919
# ไปสถานที่เสี่ยง เช่น ตลาด สถานที่ชุมชน                 1
# ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต               1006
# ไปเที่ยวสถานบันเทิงในอุบลที่พบการระบาดของโรค Ubar      1
# ไปแหล่งชุมชน/สถานที่คนหนาแน่น                          5
#
# [128 rows x 1 columns]

# %%
df.max().sort_values(ascending=False)
# Out:
# No.    303184
# dtype: int64

# %% [markdown]
# - คนที่ติดมาจากความเสี่ยงอะไรบ้าง

# %% [markdown]
# - คนที่ติดมาจากความเสี่ยง 'คนต่างชาติเดินทางมาจากต่างประเทศ' ประเทศอะไรบ้าง

# %%
df= data_civid_cases[data_civid_cases['risk']=='คนต่างชาติเดินทางมาจากต่างประเทศ']
df[['No.','nationality']].groupby('nationality').count()
# Out:
#                           No.
# nationality
# Albania                     1
# Australia                   2
# Bangladeshi                 2
# Belgium                     2
# Burma                      39
# Burmese                    32
# Cambodia                    2
# Cambodian                   3
# Canada                      2
# China                      19
# Chinese                     2
# Denmark                     2
# Filipino                    1
# Finland                     1
# France                     19
# Germany                     5
# India                       3
# Indonesia                   7
# Indonesian                  4
# Italy                       4
# Japan                       5
# Korea, South                3
# Kuwait                      1
# Laos                        1
# Liberia                     1
# Netherlands                 2
# New Zealand                 1
# Pakistan                    3
# Philippines                 3
# ...
